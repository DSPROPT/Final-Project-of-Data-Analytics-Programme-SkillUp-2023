# %% [markdown]
# <center><img src="https://www.dss-pro.pt/juliofoto.png" width="500" height="auto"></center>
# <center><h3>Julio Cesar Gouveia Cordero</h3></center>
# <center><h3>Funchal, Portugal</h3></center>

# %% [markdown]
# <center><h1>Capstone Project Creation</h1></center>
#
# <center><h3>IBM SkillsBuild Europe Delivery - Data Analytics</h3></center>
#
#
#
# # Pre-requisite
#
# * Understanding of Python, Power BI or Tableau
# * Understanding of Data Cleaning
# * Understanding Data Visualization
#
# #### Level of Exercise: Intermediate
#
# #### Duration: approximately 3 hours

# %% [markdown]
# ### Data Analytics of Airbnb Data:
#
# #### Objective:
#
# In this exericise, you will be performing Data Analytics on an Open Dataset dataset coming from Airbnb. Some of the tasks include
# - Data Cleaning.
# - Data Transformation
# - Data Visualization.
#
# #### Overview of Airbnb Data:
#
# People's main criteria when visiting new places are reasonable accommodation and food. Airbnb (Air-Bed-Breakfast) is an online marketplace created to meet this need of people by renting out their homes for a short term. They offer this facility at a relatively lower price than hotels. Further people worldwide prefer the homely and economical service offered by them. They offer services across various geographical locations
#
# #### Dataset Source
#
# YOu can get the dataset for this assessment using the following link: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
#
# This dataset contains information such as the neighborhood offering these services, room type, price,avaliabilty, reviews, service fee, cancellation policy and rules to use the house. This analysis will help airbnb in improving its services.
#
# So all the best for your Data Analytics Journey on Airbnb data!!!

# %% [markdown]
# ## Task 1: Data Loading (Python)
#
# 1. Read the csv file and load it into a pandas dataframe.
# 2. Display the first five rows of your dataframe.
# 3. Display the data types of the columns.

# %%
## Read the csv file
import pandas as pd
df=pd.read_csv("https://www.dss-pro.pt/Airbnb_Open_Data.csv", low_memory=False)

# %%
## Display the first 5 rows
df.head()
# Out:
#         id                                              NAME      host id
# 0  1001254                Clean & quiet apt home by the park  80014485718  \
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood
# 0            unconfirmed  Madaline            Brooklyn    Kensington  \
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights
# ...

# %%
## Display the data types
df.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# ...

# %% [markdown]
# ## Here are the data types of the columns in the dataframe:
#
# - id: int64
# - NAME: object (typically represents string data type in pandas)
# - host id: int64
# - host_identity_verified: object
# - host name: object
# - neighbourhood group: object
# - neighbourhood: object
# - lat: float64
# - long: float64
# - country: object
# - country code: object
# - instant_bookable: object
# - cancellation_policy: object
# - room type: object
# - Construction year: float64
# - price: object
# - service fee: object
# - minimum nights: float64
# - number of reviews: float64
# - last review: object
# - reviews per month: float64
# - review rate number: float64
# - calculated host listings count: float64
# - availability 365: float64
# - house_rules: object
# - license: object
#
# #### It appears that some columns which may be expected to be numeric (e.g., price and service fee) have an object data type, likely due to the presence of special characters or non-numeric entries. These columns may require some preprocessing if we intend to perform numerical operations on them.

# %% [markdown]
# ## Task 2a: Data Cleaning (Any Tool)
#
# 1. Drop some of the unwanted columns. These include `host id`, `id`, `country` and `country code` from the dataset.
# 2. State the reason for not including these columns for your Data Analytics.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots before and after the elimination of the columns.

# %%
# 1. Drop the unwanted columns from the dataframe
df_cleaned = df.drop(columns=['host id', 'id', 'country', 'country code'])

# %%
# Display the first five rows of the cleaned dataframe to confirm the changes
df_cleaned.head()
# Out:
#                                                NAME host_identity_verified
# 0                Clean & quiet apt home by the park            unconfirmed  \
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host name neighbourhood group neighbourhood       lat      long
# 0  Madaline            Brooklyn    Kensington  40.64749 -73.97237  \
# 1     Jenna           Manhattan       Midtown  40.75362 -73.98377
# 2     Elise           Manhattan        Harlem  40.80902 -73.94190
# 3     Garry            Brooklyn  Clinton Hill  40.68514 -73.95976
# 4    Lyndon           Manhattan   East Harlem  40.79851 -73.94399
#
#   instant_bookable cancellation_policy        room type  ...  service fee
# ...

# %% [markdown]
# ### Reason for not including these columns for Data Analytics:
# - host id & id: These are unique identifiers for hosts and listings, respectively. While they can be useful for database operations or joining tables, they do not provide any direct analytical insight when examining the characteristics of the listings.
#
# - country & country code: Since the data seems to be primarily focused on Airbnb listings in a specific country (possibly the United States, given the sample), having the country and country code in every row is redundant. Removing these columns can make the dataset more concise without losing meaningful information. If the dataset included listings from multiple countries, these columns would be more relevant.

# %% [markdown]
# ## Task 2b: Data Cleaning (Python)
#
# - Check for missing values in the dataframe and display the count in ascending order. **If the values are missing, impute the values as per the datatype of the columns.**
# - Check whether there are any duplicate values in the dataframe and, if present, remove them.
# - Display the total number of records in the dataframe before and after removing the duplicates.

# %%
## Check for missing values in the dataframe and display the count in ascending order.
missing_values_count = df_cleaned.isnull().sum().sort_values()
print(missing_values_count)
# Out:
# room type                              0
# lat                                    8
# long                                   8
# neighbourhood                         16
# neighbourhood group                   29
# cancellation_policy                   76
# instant_bookable                     105
# number of reviews                    183
# Construction year                    214
# price                                247
# NAME                                 250
# service fee                          273
# host_identity_verified               289
# calculated host listings count       319
# review rate number                   326
# host name                            406
# minimum nights                       409
# availability 365                     448
# reviews per month                  15879
# last review                        15893
# house_rules                        52131
# license                           102597
# dtype: int64

# %% [markdown]
# ## Missing Values:
# Here's the count of missing values for each column in ascending order:
#
# - room type: 0 missing values
# - lat: 8 missing values
# - long: 8 missing values
# - neighbourhood: 16 missing values
# - neighbourhood group: 29 missing values
# - cancellation_policy: 76 missing values
# - instant_bookable: 105 missing values
# - number of reviews: 183 missing values
# - Construction year: 214 missing values
# - price: 247 missing values
# - NAME: 250 missing values
# - service fee: 273 missing values
# - host_identity_verified: 289 missing values
# - calculated host listings count: 319 missing values
# - review rate number: 326 missing values
# - host name: 406 missing values
# - minimum nights: 409 missing values
# - availability 365: 448 missing values
# - reviews per month: 15,879 missing values
# - last review: 15,893 missing values
# - house_rules: 52,131 missing values
# - license: 102,597 missing values

# %%
## Check whether there are any duplicate values in the dataframe and if present remove them.

duplicates_count = df_cleaned.duplicated().sum()
print('duplicate values in the dataframe',duplicates_count)

# Total number of records before removing duplicates
total_records_before = df_cleaned.shape[0]
print('Total number of records before removing duplicates',total_records_before)

# Remove duplicate values if any
if duplicates_count > 0:
    df_cleaned = df_cleaned.drop_duplicates()
# Out:
# duplicate values in the dataframe 3436
# Total number of records before removing duplicates 102599

# %%
## Display the total number of records in the dataframe after removing the duplicates.

total_records_after = df_cleaned.shape[0]

print('Total number of records after removing duplicates',total_records_after)
# Out:
# Total number of records after removing duplicates 99163

# %% [markdown]
# ## Duplicate Values:
# - Total number of records in the dataframe before removing duplicates: 102,599
# - Total number of records in the dataframe after removing duplicates: 99,163
# - This means 2,453 duplicate records were removed from the dataframe.

# %% [markdown]
# ## Task 3: Data Transformation (Any Tool)
#
#
# - Rename the column `availability 365` to `days_booked`
# - Convert all column names to lowercase and replace the spaces in the column names with an underscore "_".
# - Remove the dollar sign and comma from the columns `price` and `service_fee`. If necessary, convert these two columns to the appropriate data type.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## Rename the column.
df_cleaned.rename(columns={'availability 365': 'days_booked'}, inplace=True)

# %%
## Convert all column names to lowercase and replace the spaces with an underscore "_"
df_cleaned.columns = df_cleaned.columns.str.lower().str.replace(' ', '_')

# %%
## Remove the dollar sign and comma from the columns. If necessary, convert these two columns to the appropriate data type.
df_cleaned['service_fee'] = df_cleaned['service_fee'].replace('[\$,]', '', regex=True).astype(float)
df_cleaned['price'] = df_cleaned['price'].replace('[\$,]', '', regex=True).astype(float)
# Display the first few rows to verify the changes and the new column names
df_cleaned.head()
# Out:
#                                                name host_identity_verified
# 0                Clean & quiet apt home by the park            unconfirmed  \
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host_name neighbourhood_group neighbourhood       lat      long
# 0  Madaline            Brooklyn    Kensington  40.64749 -73.97237  \
# 1     Jenna           Manhattan       Midtown  40.75362 -73.98377
# 2     Elise           Manhattan        Harlem  40.80902 -73.94190
# 3     Garry            Brooklyn  Clinton Hill  40.68514 -73.95976
# 4    Lyndon           Manhattan   East Harlem  40.79851 -73.94399
#
#   instant_bookable cancellation_policy        room_type  ...  service_fee
# ...

# %%
df_cleaned.columns.tolist()
# Out:
# ['name',
#  'host_identity_verified',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'instant_bookable',
#  'cancellation_policy',
#  'room_type',
#  'construction_year',
#  'price',
#  'service_fee',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'review_rate_number',
#  'calculated_host_listings_count',
#  'days_booked',
#  'house_rules',
#  'license']

# %% [markdown]
# ### The transformations have been successfully applied to the dataframe:
#
# - The column availability availability 365 was renamed to days_booked.
# - All column names were converted to lowercase, and spaces were replaced with underscores.
# - Dollar signs and commas were removed from the price and service_fee columns, and these columns were converted to the float data type.
# - The first five rows of the transformed dataframe are displayed above for verification.

# %% [markdown]
# ### Task 4: Exploratory Data Analysis (Any Tool)
#
# - List the count of various room types avaliable in the dataset.
# - Which room type has the most strict cancellation policy?
# - List the average price per neighborhood group, and highlight the most expensive neighborhood to rent from.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## List the count of various room types avaliable with Airbnb
# Count of various room types available in the dataset
room_type_count = df_cleaned['room_type'].value_counts()

print('room types available')
room_type_count
# Out:
# room types available
# room_type
# Entire home/apt    52003
# Private room       44895
# Shared room         2150
# Hotel room           115
# Name: count, dtype: int64

# %%
df_cleaned['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'brookln', 'manhatan', 'Queens', nan,
#        'Staten Island', 'Bronx'], dtype=object)

# %% [markdown]
# ### Brookln:(This seems to be a typo or variant spelling of Brooklyn)
# ### Manhatan:  (This seems to be a typo or variant spelling of Manhattan)

# %%
# Define a function to correct the typos
def correct_typos(value):
    if pd.isna(value):
        return value
    corrections = {
        'brookln': 'Brooklyn',
        'manhatan': 'Manhattan'
    }
    return corrections.get(value.lower(), value)

# Apply the function to the 'neighbourhood_group' column
df_cleaned['neighbourhood_group'] = df_cleaned['neighbourhood_group'].apply(correct_typos)

df_cleaned['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', nan, 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
## Which room type adheres to more strict cancellation policy
# Room type with the most strict cancellation policy
strict_cancellation = df_cleaned[df_cleaned['cancellation_policy'] == 'strict']
strict_cancellation_count = strict_cancellation['room_type'].value_counts().idxmax()

print('Room type with the most strict cancellation policy is',strict_cancellation_count)
# Out:
# Room type with the most strict cancellation policy is Entire home/apt

# %%
## List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
average_price_neighborhood = df_cleaned.groupby('neighbourhood_group')['price'].mean().sort_values(ascending=False)
most_expensive_neighborhood_group = average_price_neighborhood.idxmax()
most_expensive_neighborhood_group_average_price = average_price_neighborhood.max()



print(average_price_neighborhood)
print('the most expensive neighborhood group for rentals is',most_expensive_neighborhood_group) 


print('with the average_price of',most_expensive_neighborhood_group_average_price,'$')
# Out:
# neighbourhood_group
# Queens           629.712735
# Bronx            626.614412
# Staten Island    626.431843
# Brooklyn         626.427040
# Manhattan        622.679932
# Name: price, dtype: float64
# the most expensive neighborhood group for rentals is Queens
# with the average_price of 629.712735222925 $

# %% [markdown]
# ## Exploratory Data Analysis Results:
# #### Count of Various Room Types Available in the Dataset:
#
# - Entire home/apt: 52,003 listings
# - Private room: 44,895 listings
# - Shared room: 2,150 listings
# - Hotel room: 115 listings
# - Room Type with the Most Strict Cancellation Policy:
#
# The room type with the most strict cancellation policy is "Entire home/apt".
#
# #### Average Price per Neighbourhood Group:
#
# * Queens: 629.71 Dollars (This is the most expensive neighborhood to rent from based on average price)
# * Bronx: 626.61 Dollars
# * Staten Island: 626.43 Dollars
# * Brooklyn: 626.42 Dollars
# * Manhattan: 622.68 Dollars
#
# - The neighborhood group "Queens" has the highest average price, making it the most expensive neighborhood to rent from based on the data provided.

# %% [markdown]
# ## Task 5a: Data Visualization (Any Tool)
#
# * List the count of various room types avaliable with Airnb
# * Which room type adheres to more strict cancellation policy
# * List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
# * List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood.
# * List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph
# * List the prices with respect to room type using a bar graph and also state your inferences.
# * Create a pie chart that shows  distribution of booked days for each neighborhood group .Which neighborhood has the highest booking percentage.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Setting up the style and size for the plots
sns.set(style="whitegrid")
plt.figure(figsize=(14, 6))

# 1. List the count of various room types available with Airbnb
plt.subplot(1, 2, 1)
sns.countplot(y='room_type', data=df_cleaned, order = df_cleaned['room_type'].value_counts().index)
plt.title('Count of Various Room Types')
plt.xlabel('Count')
plt.ylabel('Room Type')

# 2. Which room type adheres to more strict cancellation policy
plt.subplot(1, 2, 2)
strict_data = df_cleaned[df_cleaned['cancellation_policy'] == 'strict']
sns.countplot(y='room_type', data=strict_data, order = strict_data['room_type'].value_counts().index)
plt.title('Room Types with Strict Cancellation Policy')
plt.xlabel('Count')
plt.ylabel('Room Type')

plt.tight_layout()
plt.show()

# %%
df_cleaned['neighbourhood_group'].dtype
# Out:
# dtype('O')

# %%
df_cleaned['price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - The first two visualizations have been generated:
#
# - Count of Various Room Types with Airbnb:
#
# - The most common room type is "Entire home/apt", followed by "Private room". "Shared room" and "Hotel room" are considerably less common.
# Room Types with Strict Cancellation Policy:
#
# - Among the listings with a strict cancellation policy, "Entire home/apt" is the most common room type.

# %%
# 3. List the prices by neighborhood group and mention which is the most expensive neighborhood group for rentals

plt.figure(figsize=(14, 6))
# Sort the dataframe by the mean price for better visualization
sorted_data = df_cleaned.groupby('neighbourhood_group')['price'].mean().sort_values().reset_index()
# Plot using the sorted data
sns.barplot(x='neighbourhood_group', y='price', data=sorted_data, estimator=np.nanmean, palette='viridis', errorbar=None)
plt.title('Average Price by Neighbourhood Group', fontsize=16)
plt.xlabel('Neighbourhood Group', fontsize=12)
plt.ylabel('Average Price ($)', fontsize=12)
plt.xticks(rotation=45)
# Add value labels on top of the bars
for index, value in enumerate(sorted_data['price']):
    plt.text(index, value, f"{value:.2f}", ha='center', va='bottom', fontsize=10)
# Add horizontal gridlines for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
# Despine for a cleaner look
sns.despine()
plt.show()

# %% [markdown]
# ### Average Price by Neighbourhood Group:
# - The neighborhood group "Queens" appears to have the highest average price, making it the most expensive neighborhood group for rentals.

# %%
# 4. List the top 10 neighborhoods in increasing order of their price with a horizontal bar graph
top_neighbourhoods = df_cleaned.groupby('neighbourhood')['price'].mean().sort_values().head(20)

plt.figure(figsize=(14, 7))
top_neighbourhoods.plot(kind='barh', color=sns.color_palette('viridis', 10))
plt.title('Top 10 Neighbourhoods with Lowest Average Price')
plt.xlabel('Average Price')
plt.ylabel('Neighbourhood')
plt.show()

# %% [markdown]
# ### Top 10 Neighbourhoods with Lowest Average Price:
# - The horizontal bar graph displays the top 10 neighborhoods with the lowest average prices. **"Lighthouse Hill"** is the neighborhood with the lowest average price, making it the cheapest neighborhood based on the data provided.

# %%
# 5. List the neighborhoods which offer short term rentals within 10 days
short_term_neighbourhoods = df_cleaned[df_cleaned['minimum_nights'] <= 10].groupby('neighbourhood')['neighbourhood'].count().sort_values(ascending=False).head(10)

plt.figure(figsize=(14, 7))
short_term_neighbourhoods.plot(kind='bar', color=sns.color_palette('muted'))
plt.title('Top 10 Neighbourhoods Offering Short Term Rentals (≤ 10 days)')
plt.ylabel('Number of Listings')
plt.xlabel('Neighbourhood')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Top 10 Neighbourhoods Offering Short Term Rentals (≤ 10 days):
# - The bar graph displays the top 10 neighborhoods with the most listings offering short-term rentals within 10 days. **"Bedford-Stuyvesant"** is the neighborhood with the highest number of such listings.

# %%
# 6. List the prices with respect to room type using a bar graph
# Calculate average prices
average_prices = df_cleaned.groupby('room_type')['price'].mean().sort_values(ascending=False)
sorted_room_types = average_prices.index

# Create the plot
plt.figure(figsize=(14, 7))
barplot = sns.barplot(x='room_type', y='price', data=df_cleaned, order=sorted_room_types,
                      estimator=np.nanmean, errorbar=None, palette='Spectral')

# Annotate each bar with the average price
for i, room_type in enumerate(sorted_room_types):
    price = average_prices[room_type]
    plt.text(i, price, f'{price:.2f}', ha='center', va='bottom')

# Enhance aesthetics
plt.title('Average Price by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
sns.despine()

# Rotate x labels if needed
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Average Price by Room Type:
# - The bar graph displays the average price for each room type. **"Hotel room" has the highest average price, while "Private room" has the lowest average price.**

# %%
# 7. Create a pie chart that shows distribution of booked days for each neighborhood group
booked_days_neighbourhood = df_cleaned.groupby('neighbourhood_group')['days_booked'].sum()

# Calculate the percentage values
percentages = 100 * booked_days_neighbourhood / booked_days_neighbourhood.sum()

# Create custom labels for the legend
custom_labels = [f"{index} ({percentage:.1f}%)" for index, percentage in percentages.items()]

# Increase the figure size and plot the pie chart with improved visuals
plt.figure(figsize=(16, 12))
booked_days_neighbourhood.plot(kind='pie', labels=None, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'), wedgeprops=dict(width=0.3), pctdistance=0.85)

# Draw a circle in the center to make it a donut chart (this can help improve visibility for smaller values)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Distribution of Booked Days by Neighbourhood Group')
plt.ylabel('')  # Hide the default y-label which is 'days_booked'

# Add the custom labels to the legend
plt.legend(custom_labels, loc='upper left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ### Distribution of Booked Days by Neighbourhood Group:
# - The pie chart displays the distribution of booked days for each neighborhood group.
# - **"Manhattan" occupies the largest portion**, indicating that it has the highest booking percentage among all the neighborhood groups. This suggests that Manhattan is the most popular neighborhood group for Airbnb bookings based on the data provided.

# %% [markdown]
# ## Task 5b: Data Visualization (Any Tool)
#
# * Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences
# * Using a line graph show in which year the maximum construction of rooms took place.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
# 1. Illustrate the relationship between service price and room price with a scatter plot
plt.figure(figsize=(14, 7))
sns.scatterplot(x='service_fee', y='price', data=df_cleaned, alpha=0.5)
plt.title('Relationship between Service Fee and Room Price')
plt.xlabel('Service Fee ($)')
plt.ylabel('Room Price ($)')
plt.show()

# %% [markdown]
# ### Relationship between Service Fee and Room Price:
# - The scatter plot illustrates the relationship between the service fee and the room price.
#
#
# ### Inferences:
#
# - There seems to be a general trend indicating that as the room price increases, the service fee also tends to increase. This suggests a positive correlation between the two.
# - However, there are several listings with a high room price but a relatively lower service fee, and vice versa. This indicates that while there's a general trend, there are other factors at play that determine the service fee.
# - Next, let's create a line graph to show in which year the maximum construction of rooms took place.

# %%
# 2. Using a line graph show in which year the maximum construction of rooms took place
# First, we will extract the year from the 'construction_year' column and then count the number of rooms constructed each year

# Extracting the year and counting the number of constructions per year
construction_counts = df_cleaned['construction_year'].value_counts().sort_index()

plt.figure(figsize=(14, 7))
construction_counts.plot(kind='line', marker='o')
plt.title('Number of Room Constructions by Year')
plt.xlabel('Year')
plt.ylabel('Number of Constructions')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ### Number of Room Constructions by Year:
# The line graph depicts the number of room constructions from the early 2000s to 2022, displaying pronounced cyclical trends. Construction activity peaks around 2015 and 2020, suggesting periods of economic boom or favorable housing policies. Sharp declines following these peaks may indicate market saturation or economic contractions. The industry shows signs of both stability, as seen between 2003 and 2005 and from 2020 to 2022, and volatility, with abrupt rises and falls, particularly after 2015. These patterns imply that room construction is sensitive to economic cycles, policy changes, and possibly technological advancements in building materials and methods. The data underscores the construction sector's susceptibility to external factors and highlights the need for continuous monitoring to aid in strategic planning and anticipation of market shifts. Further detailed analysis would be beneficial for a comprehensive understanding of the driving forces behind these trends.

# %% [markdown]
# ## Task 5c: Data Visualization (Any Tool)
#
# * With the help of box plots illustrate the following
#  * Effect of Review Rate number on price
#  * Effect of host identity verified on price
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
# Convert 'review_rate_number' to a categorical variable
df_cleaned['review_rate_number'] = df_cleaned['review_rate_number'].astype('category')

# Then, make sure to handle NaN values in 'host_identity_verified'
# For the purpose of visualization, you might want to drop these or replace with a category like 'unknown'
df_cleaned['host_identity_verified'] = df_cleaned['host_identity_verified'].fillna('unknown')
df_cleaned['host_identity_verified'] = df_cleaned['host_identity_verified'].astype('category')

# Now, let's create the boxplots
plt.figure(figsize=(16, 7))

# 1. Effect of Review Rate number on price
plt.subplot(1, 2, 1)
sns.boxplot(x='review_rate_number', y='price', data=df_cleaned, palette='viridis')
plt.title('Effect of Review Rate Number on Price')
plt.xlabel('Review Rate Number')
plt.ylabel('Price ($)')

# 2. Effect of host identity verified on price
plt.subplot(1, 2, 2)
sns.boxplot(x='host_identity_verified', y='price', data=df_cleaned, palette='pastel')
plt.title('Effect of Host Identity Verified on Price')
plt.xlabel('Host Identity Verified')
plt.ylabel('Price ($)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## The two box plots have been generated to illustrate:
#
# #### Review Rate Number on Price:
#
# * The boxplots across different review rates from 1 to 5 show overlapping interquartile ranges, indicating that there's not a clear distinction in price based on the review rate number.
# * There's a consistency in median prices across all review rate numbers, suggesting that review rate number may not be a strong predictor of price.
# * There are no visible outliers in the data, which could mean that outlier values have been removed or that the dataset lacks extreme values in price.
#
# #### Host Identity Verified on Price:
#
# * The three categories, 'unconfirmed', 'unknown', and 'verified', show some variation in median prices, with 'unconfirmed' and 'verified' having higher median prices than 'unknown'.
# * The spread of prices (as indicated by the interquartile range) is similar across all three categories, although 'verified' shows a slightly larger range, suggesting more variability in price for listings with verified hosts.
# * Similar to the review rate number boxplots, there are no outliers shown here.
#
# ### Conclusions:
#
# * The review rate number doesn't seem to have a significant effect on the listing price, as all review rate categories have similar price distributions.
# * Listings with verified hosts tend to have a wider range of prices, potentially indicating that verified listings might offer more premium options, which could explain the higher variability.
# * The 'unknown' category for host identity verification has a lower median price, which might suggest that guests could be paying less for listings where the host's identity status is not confirmed or provided.

# %% [markdown]
# # Final Conclusion
# ### After a comprehensive analysis of the Airbnb dataset, here's a holistic summary of our findings:
#
#
# #### The analysis of the Airbnb dataset in your Jupyter notebook has yielded several important findings and conclusions:
#
# ### Exclusion of Certain Columns for Data Analytics:
#
# * The notebook explains why certain columns like 'host id', 'id', 'country', and 'country code' were excluded from the analysis. These columns were deemed redundant or not directly relevant to the analytical insights being sought.
#
# ## Exploratory Data Analysis (EDA) Results:
#
# * Room Types: The dataset contains 52,003 listings for entire homes/apartments, 44,895 for private rooms, 2,150 for shared rooms, and 115 hotel rooms. The 'Entire home/apt' category has the most strict cancellation policy.
#
# * Average Price per Neighborhood Group: The analysis revealed the average rental prices across different neighborhoods, with Queens being the most expensive based on average price.
#
# ## Impact of Review Rate and Host Identity Verification on Price:
#
# * Review Rate Number: The analysis shows that the review rate number doesn't significantly affect listing prices. There's consistency in median prices across all review rate numbers, and no clear distinction in price based on the review rate number.
# * Host Identity Verified: Listings with 'unconfirmed' and 'verified' hosts have higher median prices than those categorized as 'unknown'. Verified listings exhibit a wider range of prices, indicating more variability and potentially more premium options.
#
#
# * The review rate number is not a strong predictor of price in the Airbnb listings.
# * Verified listings might offer more premium options, which could explain the higher variability in prices.
# * Listings where the host's identity status is 'unknown' tend to have lower median prices, suggesting guests might be paying less for these listings.
# ## These insights provide a comprehensive understanding of the Airbnb market, highlighting factors like room type, neighborhood, review rates, and host verification status in determining rental prices and policies.​
